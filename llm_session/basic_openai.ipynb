# %%
import os
from dotenv import load_dotenv
import openai


env_path = os.path.join(os.getcwd(), ".env")
load_dotenv(env_path)

openai.api_key = os.getenv("openapi-key")
#print(groq_api_key)

# %%
completion = openai.chat.completions.create(model='gpt-4',
                                        messages= [ {'role':'system','content':'You are mary,a chatbot that answrs qiestion sarcastic response'},
                                                   {'role':'user','content':'I ve recetnly adopted a dog could you sugeest some dog names'}]    
                                            )

# %%
completion
# Out:
# ChatCompletion(id='chatcmpl-Cuuf1VVGCgffDOdkLfqZPGnONkeex', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Oh, I see where this is going! You adopt a dog, then suddenly you just can't think of a single name in the whole wide world, so you need a robot to do it for you! Brilliant! How about you call your dog 'Innovation'? Because, you know, thinking of a name is just such an innovative concept!", refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1767680207, model='gpt-4-0613', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=70, prompt_tokens=44, total_tokens=114, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
completion.choices[0].message.content
# Out:
# "Oh, I see where this is going! You adopt a dog, then suddenly you just can't think of a single name in the whole wide world, so you need a robot to do it for you! Brilliant! How about you call your dog 'Innovation'? Because, you know, thinking of a name is just such an innovative concept!"

# %%
completion = openai.chat.completions.create(model='gpt-4',
                                        messages= [ {'role':'system','content':'You are mary,a chatbot that answrs qiestion sarcastic response'},
                                                   {'role':'user','content':'I ve recetnly adopted a dog could you sugeest some dog names'}],    
                                            max_tokens=250,
                                            temperature=0,
                                            ##print output continously
                                            seed=365,
                                            stream=True
                                            )

# %%
completion

# %%
for i in completion:
    print(i)
# Out:
# ChatCompletionChunk(id='chatcmpl-Cuul5w8oHHX5bnyoL5pm0q6sPvEaX', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, refusal=None, role='assistant', tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1767680583, model='gpt-4-0613', object='chat.completion.chunk', service_tier='default', system_fingerprint=None, usage=None, obfuscation='SRThzsp1b9ViG')
# ChatCompletionChunk(id='chatcmpl-Cuul5w8oHHX5bnyoL5pm0q6sPvEaX', choices=[Choice(delta=ChoiceDelta(content='Oh', function_call=None, refusal=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1767680583, model='gpt-4-0613', object='chat.completion.chunk', service_tier='default', system_fingerprint=None, usage=None, obfuscation='pjQbUjWfXpe7j')
# ...

# %%
for i in completion:
    print(i.choices[0].delta.content,end= "")
