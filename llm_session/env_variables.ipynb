# %%
import os

# %%
os.environ.items()
# Out:
# ItemsView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'AMDRMSDKPATH': 'C:\\Program Files\\AMD\\RyzenMasterSDK\\', 'APPDATA': 'C:\\Users\\Karthik\\AppData\\Roaming', 'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey', 'CHOCOLATEYLASTPATHUPDATE': '134105234542923987', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_32200_PHFBFBRUQJAXZCSU', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'LAPTOP-UN19TNQV', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'CONDA_ALLOW_SOFTLINKS': 'false', 'CONDA_BAT': 'C:\\Users\\Karthik\\anaconda3\\condabin\\conda.bat', 'CONDA_DEFAULT_ENV': '360course', 'CONDA_EXE': 'C:\\Users\\Karthik\\anaconda3\\Scripts\\conda.exe', 'CONDA_EXES': '"C:\\Users\\Karthik\\anaconda3\\Scripts\\conda.exe"  ', 'CONDA_PREFIX': 'C:\\Users\\Karthik\\anaconda3\\envs\\360course', 'CONDA_PROMPT_MODIFIER': '(360course) ', 'CONDA_PYT
# ...

# %%
for key,value in os.environ.items():
    print(f"{key}:{value}")
# Out:
# ALLUSERSPROFILE:C:\ProgramData
# AMDRMSDKPATH:C:\Program Files\AMD\RyzenMasterSDK\
# APPDATA:C:\Users\Karthik\AppData\Roaming
# CHOCOLATEYINSTALL:C:\ProgramData\chocolatey
# CHOCOLATEYLASTPATHUPDATE:134105234542923987
# CHROME_CRASHPAD_PIPE_NAME:\\.\pipe\crashpad_32200_PHFBFBRUQJAXZCSU
# COMMONPROGRAMFILES:C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86):C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432:C:\Program Files\Common Files
# COMPUTERNAME:LAPTOP-UN19TNQV
# COMSPEC:C:\WINDOWS\system32\cmd.exe
# CONDA_ALLOW_SOFTLINKS:false
# CONDA_BAT:C:\Users\Karthik\anaconda3\condabin\conda.bat
# CONDA_DEFAULT_ENV:360course
# CONDA_EXE:C:\Users\Karthik\anaconda3\Scripts\conda.exe
# CONDA_EXES:"C:\Users\Karthik\anaconda3\Scripts\conda.exe"
# CONDA_PREFIX:C:\Users\Karthik\anaconda3\envs\360course
# CONDA_PROMPT_MODIFIER:(360course)
# CONDA_PYTHON_EXE:C:\Users\Karthik\anaconda3\python.exe
# CONDA_ROOT:C:\Users\Karthik\anaconda3
# CONDA_SHLVL:1
# ...

# %%
# %load_ext dotenv
# %dotenv
